# %%
import pandas as pd
df = pd.read_csv('table_1.csv')

# Display the DataFrame
df.tail()
# Out:
#     Unnamed: 0 US$ FY    FY  FY.1  FY.2  FY.3  FY.4  FY.5  FY.6  FY.7  ...  \
# 48         NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 49  RONW (%)**  -15.0  13.2  13.1  12.7  15.1  16.9  16.4  16.5  13.5  ...
# 50         NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 51  ROCE (%)**  -13.3  12.7  10.6  12.0  13.5  13.6  13.5  13.0  12.8  ...
# 52         NaN    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#    Unnamed: 2 FY.10 FY.11 FY.12 FY.13 FY.14 FY.15 FY.16 FY.17 FY.18
# 48        NaN  14.5  10.1  16.2  24.9  28.7  25.4  17.2  12.7  11.5
# 49        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 50        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 51        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 52        NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 24 columns]

# %%
import numpy as np

sentences = [
    "It's such a beautiful day outside.",
    "The weather is amazing today.",
    "She programmed a chatbot using Python.",
    "The detective found a hidden clue."
]
import torch

# Manual vector representation (for Desmos 3D visualization)
vectors = torch.tensor(np.array([
    [10.0, 15.0, 20.0],  # Beautiful day outside
    [12.0, 16.0, 18.0],  # Amazing weather
    [5.0 , -8.0, -3.0],    # Python chatbot
    [-15.0, -6.0, 8.0]     # Hidden clue
]), dtype=torch.float32)

def consine_similarity(input_embedding, sentence_embeddings):
  # calculate cosine_similarity of input_embedding and each of the sentence_embeddings
  # input_embedding: tensor of shape (1,384)
  # sentence_embeddings: tensor of shape (50, 384)
  # returns: tensor of shape (50)
  prod = torch.matmul(input_embedding,sentence_embeddings.T)
  prod /= torch.norm(input_embedding, dim=1, keepdim=True)
  prod /= torch.norm(sentence_embeddings, dim=1, keepdim=True).T
  return prod
query = torch.tensor(np.array([[11, 14, 13]]), dtype=torch.float32)
print(query.shape)
# Calculate cosine similarity
similarity_matrix = consine_similarity(query, vectors)

print("Vectors:")
for i, vec in enumerate(vectors):
    print(f"Sentence {i+1}: {sentences[i]} - Vector: {vec}")

print("\nCosine Similarity Matrix:")
print(similarity_matrix)
# Out:
# torch.Size([1, 3])
# Vectors:
# Sentence 1: It's such a beautiful day outside. - Vector: tensor([10., 15., 20.])
# Sentence 2: The weather is amazing today. - Vector: tensor([12., 16., 18.])
# Sentence 3: She programmed a chatbot using Python. - Vector: tensor([ 5., -8., -3.])
# Sentence 4: The detective found a hidden clue. - Vector: tensor([-15.,  -6.,   8.])
#
# Cosine Similarity Matrix:
# tensor([[ 0.9771,  0.9946, -0.4399, -0.3648]])

# %%
import os
import tempfile
import pytesseract
from pdf2image import convert_from_path
from PIL import Image

def ocr_pdf(pdf_path, output_folder=None, language='eng', dpi=300):
    """
    Extract text from a PDF using Tesseract OCR.
    
    Args:
        pdf_path (str): Path to the PDF file
        output_folder (str, optional): Folder to save extracted text files. If None, doesn't save files.
        language (str, optional): Tesseract language code. Default is 'eng' for English. 
                                 Use '+' to combine languages, e.g., 'eng+fra' for English and French.
        dpi (int, optional): DPI for PDF to image conversion. Higher values give better quality but slower processing.
    
    Returns:
        list: List of dictionaries with page number and extracted text for each page
    """
    results = []
    
    # Create output folder if specified and doesn't exist
    if output_folder and not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    # Create a temporary directory for images
    with tempfile.TemporaryDirectory() as temp_dir:
        print(f"Converting PDF to images (DPI: {dpi})...")
        
        # Convert PDF to images
        images = convert_from_path(
            pdf_path, 
            dpi=dpi,
            output_folder=temp_dir,
            fmt='png',
            thread_count=os.cpu_count()
        )
        
        print(f"Converted {len(images)} pages. Starting OCR process...")
        
        # Process each page
        for i, image in enumerate(images):
            page_num = i + 1
            print(f"Processing page {page_num}/{len(images)}...")
            
            # Improve image quality for OCR
            image = preprocess_image(image)
            
            # Apply OCR to the image
            text = pytesseract.image_to_string(image, lang=language)
            
            # Save the extracted text to a file if output folder is specified
            if output_folder:
                output_file = os.path.join(output_folder, f"page_{page_num}.txt")
                with open(output_file, 'w', encoding='utf-8') as f:
                    f.write(text)
            
            # Add result to list
            results.append({
                'page': page_num,
                'text': text
            })
            
    return results

def preprocess_image(image):
    """
    Preprocess image to improve OCR quality.
    
    Args:
        image (PIL.Image): Original image
        
    Returns:
        PIL.Image: Processed image
    """
    # Convert to grayscale
    image = image.convert('L')
    
    # Optional: Add more preprocessing steps if needed for your specific documents
    # Examples:
    # - image = image.filter(ImageFilter.SHARPEN)  # Sharpen image
    # - image = ImageOps.autocontrast(image)  # Increase contrast
    
    return image

def ocr_pdf_with_bbox(pdf_path, language='eng', dpi=300):
    """
    Extract text with bounding boxes from a PDF using Tesseract OCR.
    
    Args:
        pdf_path (str): Path to the PDF file
        language (str, optional): Tesseract language code. Default is 'eng'.
        dpi (int, optional): DPI for PDF to image conversion. Higher values give better quality.
    
    Returns:
        list: List of dictionaries with page number and extracted text data including bounding boxes
    """
    results = []
    
    # Create a temporary directory for images
    with tempfile.TemporaryDirectory() as temp_dir:
        # Convert PDF to images
        images = convert_from_path(
            pdf_path, 
            dpi=dpi,
            output_folder=temp_dir,
            fmt='png',
            thread_count=os.cpu_count()
        )
        
        # Process each page
        for i, image in enumerate(images):
            page_num = i + 1
            
            # Improve image quality for OCR
            image = preprocess_image(image)
            
            # Get OCR data with bounding boxes
            ocr_data = pytesseract.image_to_data(
                image, 
                lang=language,
                output_type=pytesseract.Output.DICT
            )
            
            # Group OCR data into structured format
            page_data = {
                'page': page_num,
                'width': image.width,
                'height': image.height,
                'elements': []
            }
            
            # Process text elements with their positions
            n_boxes = len(ocr_data['text'])
            for j in range(n_boxes):
                # Skip empty text
                if int(ocr_data['conf'][j]) > 0:  # Filter by confidence
                    element = {
                        'text': ocr_data['text'][j],
                        'confidence': ocr_data['conf'][j],
                        'bbox': {
                            'x': ocr_data['left'][j],
                            'y': ocr_data['top'][j],
                            'width': ocr_data['width'][j],
                            'height': ocr_data['height'][j]
                        },
                        'block_num': ocr_data['block_num'][j],
                        'line_num': ocr_data['line_num'][j],
                        'word_num': ocr_data['word_num'][j]
                    }
                    page_data['elements'].append(element)
            
            results.append(page_data)
            
    return results

def main():
    """Main function to demonstrate usage."""
    pdf_path = "RIL-70-21.pdf"  # Change to your PDF file
    output_folder = "ocr_output"
    
    # Basic OCR
    print("Running OCR on PDF...")
    ocr_results = ocr_pdf(pdf_path, output_folder)
    
    # Print summary
    print("\nOCR Results Summary:")
    for page in ocr_results:
        print(f"Page {page['page']}: {len(page['text'])} characters extracted.")
    
    # Optionally, demonstrate the bounding box functionality
    print("\nExtract text with layout information...")
    layout_results = ocr_pdf_with_bbox(pdf_path)
    
    print(f"\nProcessed {len(layout_results)} pages with layout information.")
    print(f"Text files saved to {output_folder}")


main()

# %%
from doctr.io import DocumentFile
from doctr.models import ocr_predictor

# %%
import time
start_time = time.time()
print("Loading OCR model...")
model = ocr_predictor(pretrained=True)
end_time = time.time()
print(f"Model loaded in {end_time - start_time:.2f} seconds")
# PDF
start_doc_time = time.time()
doc = DocumentFile.from_pdf("scanned.pdf")
# Analyze
result = model(doc)
end_doc_time = time.time()
print(f"Document processing time: {end_doc_time - start_doc_time:.2f} seconds")
print(result)
# Out:
# Loading OCR model...
# Downloading https://doctr-static.mindee.com/models?id=v0.8.1/fast_base-688a8b34.pt&src=0 to /Users/swastikagrawal/.cache/doctr/models/fast_base-688a8b34.pt
#   0%|          | 0/65814772 [00:00<?, ?it/s]
# Downloading https://doctr-static.mindee.com/models?id=v0.3.1/crnn_vgg16_bn-9762b0b0.pt&src=0 to /Users/swastikagrawal/.cache/doctr/models/crnn_vgg16_bn-9762b0b0.pt
#   0%|          | 0/63286381 [00:00<?, ?it/s]
# Model loaded in 8.28 seconds
# Document(
#   (pages): [
#     Page(
#       dimensions=(1660, 1190)
#       (blocks): [Block(
#         (lines): [
#           Line(
#             (words): [
#               Word(value='SWASTI', confidence=0.35),
#               Word(value='AG', confidence=0.9),
#               Word(value='RAWAL', confidence=0.68),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='CMSC351', confidence=0.99),
#               Word(value='Spring', confidence=0.99),
#               Word(value='2025', confidence=1.0),
#               Word(value='$0101,90201,90301)', confidence=0.57),
#               Word(value='Homework', confidence=0.65),
#               Word(value='7', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='Due', confidence=1.0),
#               Word(value='WEDNESDAY', confidence=0.94),
#               Word(value='Apr', confidence=1.0),
#               Word(value='2,', confidence=0.99),
#               Word(value='2025', confidence=1.0),
#               Word(value='by', confidence=1.0),
#               Word(value='23:59', confidence=1.0),
#               Word(value='on', confidence=1.0),
#               Word(value='Gradescope.', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [Word(value='Directions:', confidence=1.0)]
#           ),
#           Line(
#             (words): [
#               Word(value='Homework', confidence=1.0),
#               Word(value='must', confidence=1.0),
#               Word(value='be', confidence=1.0),
#               Word(value='done', confidence=1.0),
#               Word(value='on', confidence=0.99),
#               Word(value='printouts', confidence=1.0),
#               Word(value='of', confidence=1.0),
#               Word(value='these', confidence=1.0),
#               Word(value='sheets', confidence=1.0),
#               Word(value='and', confidence=1.0),
#               Word(value='then', confidence=1.0),
#               Word(value='scanned', confidence=0.94),
#               Word(value='properly,', confidence=1.0),
#               Word(value='or', confidence=1.0),
#               Word(value='via', confidence=1.0),
#               Word(value='latex,', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='or', confidence=1.0),
#               Word(value='by', confidence=1.0),
#               Word(value='downloading,', confidence=1.0),
#               Word(value='writing', confidence=0.88),
#               Word(value='on', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='PDF,', confidence=1.0),
#               Word(value='and', confidence=1.0),
#               Word(value='uploading.', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='Do', confidence=0.95),
#               Word(value='not', confidence=1.0),
#               Word(value='use', confidence=1.0),
#               Word(value='your', confidence=1.0),
#               Word(value='own', confidence=1.0),
#               Word(value='blank', confidence=1.0),
#               Word(value='paper!', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='The', confidence=1.0),
#               Word(value='reason', confidence=1.0),
#               Word(value='for', confidence=1.0),
#               Word(value='this', confidence=1.0),
#               Word(value='is', confidence=1.0),
#               Word(value='that', confidence=0.99),
#               Word(value='gradescope', confidence=0.9),
#               Word(value='will', confidence=0.95),
#               Word(value='be', confidence=1.0),
#               Word(value='following', confidence=1.0),
#               Word(value='this', confidence=1.0),
#               Word(value='template', confidence=1.0),
#               Word(value='to', confidence=1.0),
#               Word(value='locate', confidence=0.97),
#               Word(value='the', confidence=1.0),
#               Word(value='answers', confidence=0.85),
#               Word(value='to', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='the', confidence=1.0),
#               Word(value='problems', confidence=1.0),
#               Word(value='sO', confidence=0.61),
#               Word(value='if', confidence=1.0),
#               Word(value='your', confidence=1.0),
#               Word(value='answers', confidence=1.0),
#               Word(value='are', confidence=1.0),
#               Word(value='organized', confidence=1.0),
#               Word(value='differently', confidence=0.99),
#               Word(value='they', confidence=0.7),
#               Word(value='will', confidence=0.76),
#               Word(value='not', confidence=1.0),
#               Word(value='be', confidence=1.0),
#               Word(value='recognized.', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='Tagging', confidence=1.0),
#               Word(value='is', confidence=1.0),
#               Word(value='automatic,', confidence=0.98),
#               Word(value='do', confidence=1.0),
#               Word(value='not', confidence=1.0),
#               Word(value='manually', confidence=0.99),
#               Word(value='tag.', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='1.', confidence=1.0),
#               Word(value='Suppose', confidence=1.0),
#               Word(value='we', confidence=1.0),
#               Word(value='draw', confidence=0.95),
#               Word(value='a', confidence=1.0),
#               Word(value='decision', confidence=0.99),
#               Word(value='tree', confidence=1.0),
#               Word(value='for', confidence=1.0),
#               Word(value='Bubble', confidence=1.0),
#               Word(value='Sort', confidence=1.0),
#               Word(value='applied', confidence=0.51),
#               Word(value='to', confidence=1.0),
#               Word(value='a', confidence=1.0),
#               Word(value='list', confidence=1.0),
#               Word(value='of', confidence=1.0),
#               Word(value='length', confidence=0.99),
#               Word(value='n.', confidence=0.66),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='(a)', confidence=1.0),
#               Word(value='What', confidence=1.0),
#               Word(value='will', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='height', confidence=1.0),
#               Word(value='of', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='tree', confidence=1.0),
#               Word(value='be?', confidence=1.0),
#               Word(value='Simplify', confidence=0.92),
#               Word(value='your', confidence=1.0),
#               Word(value='answer.', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='[5', confidence=0.8),
#               Word(value='pts]', confidence=0.55),
#             ]
#           ),
#           Line(
#             (words): [Word(value='6)', confidence=0.64)]
#           ),
#           Line(
#             (words): [Word(value='Height', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='2', confidence=0.86)]
#           ),
#           Line(
#             (words): [
#               Word(value='(b)', confidence=0.99),
#               Word(value='Explain.', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='[10', confidence=0.98),
#               Word(value='pts]', confidence=0.73),
#             ]
#           ),
#           Line(
#             (words): [Word(value='Solution:', confidence=1.0)]
#           ),
#           Line(
#             (words): [
#               Word(value='FoM', confidence=0.56),
#               Word(value='aL', confidence=0.5),
#               Word(value='list', confidence=0.41),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='9', confidence=0.94),
#               Word(value='ulmenls', confidence=0.57),
#               Word(value='Hhe', confidence=0.2),
#             ]
#           ),
#           Line(
#             (words): [Word(value='oy', confidence=0.33)]
#           ),
#           Line(
#             (words): [Word(value='1', confidence=0.55)]
#           ),
#           Line(
#             (words): [
#               Word(value='inst', confidence=0.56),
#               Word(value='paws', confidence=0.4),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='would', confidence=0.51),
#               Word(value='comparrl', confidence=0.24),
#               Word(value='m-1', confidence=0.46),
#               Word(value='sww', confidence=0.22),
#             ]
#           ),
#           Line(
#             (words): [Word(value='Hun', confidence=0.22)]
#           ),
#           Line(
#             (words): [Word(value='w-2', confidence=0.23)]
#           ),
#           Line(
#             (words): [Word(value='(w-D)', confidence=0.46)]
#           ),
#           Line(
#             (words): [
#               Word(value='lun', confidence=0.31),
#               Word(value='m-3', confidence=0.44),
#             ]
#           ),
#           Line(
#             (words): [Word(value='pasts', confidence=0.3)]
#           ),
#           Line(
#             (words): [Word(value='1-4', confidence=0.55)]
#           ),
#           Line(
#             (words): [
#               Word(value='audl', confidence=0.43),
#               Word(value='So', confidence=0.93),
#               Word(value='oW', confidence=0.25),
#             ]
#           ),
#           Line(
#             (words): [Word(value='V', confidence=0.69)]
#           ),
#           Line(
#             (words): [Word(value='Holao', confidence=0.27)]
#           ),
#           Line(
#             (words): [Word(value='-', confidence=0.46)]
#           ),
#           Line(
#             (words): [
#               Word(value='Thwujoe', confidence=0.42),
#               Word(value='/', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='Comparusons', confidence=0.42),
#               Word(value='QU', confidence=0.34),
#               Word(value=':', confidence=0.99),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='S2:', confidence=0.31),
#               Word(value='lw-t)', confidence=0.51),
#             ]
#           ),
#           Line(
#             (words): [Word(value='l:', confidence=0.29)]
#           ),
#           Line(
#             (words): [Word(value='2', confidence=1.0)]
#           ),
#           Line(
#             (words): [
#               Word(value='which', confidence=0.75),
#               Word(value='hhe', confidence=0.3),
#               Word(value='wa', confidence=0.47),
#               Word(value='X1', confidence=0.21),
#               Word(value='WIw', confidence=0.46),
#               Word(value='dopth', confidence=0.5),
#               Word(value='o', confidence=0.45),
#               Word(value='Ju', confidence=0.22),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='dodision', confidence=0.5),
#               Word(value='uo', confidence=0.61),
#               Word(value='oke', confidence=0.4),
#               Word(value='Whi', confidence=0.16),
#               Word(value='luigl', confidence=0.59),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='Cuvtn', confidence=0.66),
#               Word(value='', confidence=0.38),
#               Word(value='th', confidence=0.4),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='Su', confidence=0.58),
#               Word(value='varuo', confidence=0.56),
#               Word(value='isw't', confidence=0.51),
#               Word(value='woisl', confidence=0.49),
#               Word(value='Cas', confidence=0.64),
#               Word(value='cowpavrisovs', confidence=0.47),
#               Word(value='vill', confidence=0.37),
#             ]
#           ),
#           Line(
#             (words): [Word(value='7', confidence=0.2)]
#           ),
#           Line(
#             (words): [
#               Word(value='S', confidence=0.61),
#               Word(value='ll', confidence=0.33),
#               Word(value='happiw,', confidence=0.44),
#               Word(value='So', confidence=0.97),
#               Word(value='owig', confidence=0.3),
#               Word(value='huigl', confidence=0.55),
#               Word(value='would', confidence=0.54),
#               Word(value='&', confidence=0.44),
#               Word(value='TWe', confidence=0.24),
#               Word(value='cow)', confidence=0.36),
#             ]
#           ),
#         ]
#         (artefacts): []
#       )]
#     ),
#     Page(
#       dimensions=(1624, 1190)
#       (blocks): [Block(
#         (lines): [
#           Line(
#             (words): [
#               Word(value='2.', confidence=1.0),
#               Word(value='Explain', confidence=1.0),
#               Word(value='why', confidence=1.0),
#               Word(value='for', confidence=1.0),
#               Word(value='any', confidence=1.0),
#               Word(value='sorting', confidence=0.99),
#               Word(value='algorithm', confidence=0.99),
#               Word(value='(not', confidence=0.99),
#               Word(value='just', confidence=1.0),
#               Word(value='comparison-based', confidence=0.97),
#               Word(value='ones)', confidence=1.0),
#               Word(value='which', confidence=1.0),
#               Word(value='works', confidence=1.0),
#               Word(value='by', confidence=1.0),
#               Word(value='moving', confidence=0.99),
#               Word(value='[10', confidence=0.89),
#               Word(value='pts', confidence=0.64),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='elements', confidence=0.99),
#               Word(value='around', confidence=1.0),
#               Word(value='that', confidence=1.0),
#               Word(value='for', confidence=1.0),
#               Word(value='any', confidence=1.0),
#               Word(value='n', confidence=0.93),
#               Word(value='there', confidence=1.0),
#               Word(value='is', confidence=1.0),
#               Word(value='at', confidence=1.0),
#               Word(value='least', confidence=1.0),
#               Word(value='one', confidence=1.0),
#               Word(value='list', confidence=1.0),
#               Word(value='which', confidence=1.0),
#               Word(value='will', confidence=1.0),
#               Word(value='take', confidence=1.0),
#               Word(value='at', confidence=1.0),
#               Word(value='least', confidence=1.0),
#               Word(value='C(n', confidence=0.99),
#               Word(value='=', confidence=0.61),
#               Word(value='1)', confidence=1.0),
#               Word(value='time', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='for', confidence=1.0),
#               Word(value='some', confidence=1.0),
#               Word(value='constant', confidence=0.58),
#               Word(value='C', confidence=1.0),
#               Word(value='to', confidence=1.0),
#               Word(value='sort', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='list.', confidence=0.95),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='Note:', confidence=0.99),
#               Word(value='This', confidence=1.0),
#               Word(value='does', confidence=1.0),
#               Word(value='not', confidence=1.0),
#               Word(value='need', confidence=1.0),
#               Word(value='to', confidence=1.0),
#               Word(value='be', confidence=0.99),
#               Word(value='a', confidence=1.0),
#               Word(value='formal', confidence=0.99),
#               Word(value='proof', confidence=1.0),
#               Word(value='but', confidence=1.0),
#               Word(value='should', confidence=0.92),
#               Word(value='be', confidence=1.0),
#               Word(value='a', confidence=1.0),
#               Word(value='concise', confidence=0.95),
#               Word(value='explanation.', confidence=0.96),
#             ]
#           ),
#           Line(
#             (words): [Word(value='Solution:', confidence=1.0)]
#           ),
#           Line(
#             (words): [
#               Word(value='soy', confidence=0.52),
#               Word(value='led', confidence=0.39),
#               Word(value='list,', confidence=0.92),
#               Word(value='Scuy', confidence=0.89),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='1hs', confidence=0.3),
#               Word(value='cowsidwe', confidence=0.74),
#               Word(value='0', confidence=0.44),
#               Word(value='Jtwuwst', confidence=0.33),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='LfS', confidence=0.21),
#               Word(value='3,2', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='S-lh', confidence=0.4),
#               Word(value='lewws', confidence=0.25),
#               Word(value='QULR', confidence=0.34),
#               Word(value='in', confidence=0.69),
#               Word(value='He', confidence=0.47),
#               Word(value='wKog', confidence=0.29),
#               Word(value='spol', confidence=0.45),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='Caw', confidence=0.59),
#               Word(value='Jwty', confidence=0.5),
#               Word(value='lisl', confidence=0.28),
#               Word(value='Woould', confidence=0.49),
#               Word(value='hawe', confidence=0.5),
#               Word(value='wwury', confidence=0.21),
#               Word(value='wew', confidence=0.46),
#               Word(value='j', confidence=0.69),
#               Word(value='dWw', confidence=0.53),
#               Word(value='wpovg', confidence=0.56),
#             ]
#           ),
#           Line(
#             (words): [Word(value='Sol).', confidence=0.57)]
#           ),
#           Line(
#             (words): [Word(value='awonk', confidence=0.7)]
#           ),
#           Line(
#             (words): [
#               Word(value='wG', confidence=0.68),
#               Word(value='uld', confidence=0.78),
#             ]
#           ),
#           Line(
#             (words): [Word(value='oV', confidence=0.56)]
#           ),
#           Line(
#             (words): [Word(value='aouvd,ul', confidence=0.44)]
#           ),
#           Line(
#             (words): [
#               Word(value='So', confidence=0.99),
#               Word(value='a', confidence=0.28),
#               Word(value='wt', confidence=0.51),
#               Word(value='stely', confidence=0.31),
#             ]
#           ),
#           Line(
#             (words): [Word(value='moving', confidence=0.64)]
#           ),
#           Line(
#             (words): [
#               Word(value='uock', confidence=0.49),
#               Word(value='opurtalioy', confidence=0.44),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='mud', confidence=0.41),
#               Word(value='to', confidence=0.54),
#               Word(value='furjpvewn', confidence=0.42),
#               Word(value='6-1)', confidence=0.45),
#               Word(value='opcolfons',', confidence=0.3),
#             ]
#           ),
#           Line(
#             (words): [Word(value='Maf', confidence=0.36)]
#           ),
#           Line(
#             (words): [
#               Word(value='Bs', confidence=0.34),
#               Word(value='Pwer', confidence=0.42),
#               Word(value='mugt', confidence=0.42),
#               Word(value='exist', confidence=0.96),
#               Word(value='a', confidence=0.85),
#               Word(value='ligl', confidence=0.7),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='lalus', confidence=0.57),
#               Word(value='C', confidence=1.0),
#               Word(value='Covsle', confidence=0.55),
#               Word(value='ylime,', confidence=0.18),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='Jalus', confidence=0.72),
#               Word(value='odleost', confidence=0.47),
#               Word(value='CGw-D', confidence=0.62),
#               Word(value='jaxt', confidence=0.43),
#               Word(value='avy', confidence=0.55),
#               Word(value='sorlng', confidence=0.45),
#               Word(value='agorlhm,', confidence=0.51),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='3.', confidence=1.0),
#               Word(value='What', confidence=1.0),
#               Word(value='would', confidence=1.0),
#               Word(value='be', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='(simplified)', confidence=0.97),
#               Word(value='time', confidence=1.0),
#               Word(value='complexity', confidence=1.0),
#               Word(value='of', confidence=1.0),
#               Word(value='using', confidence=1.0),
#               Word(value='Counting', confidence=0.96),
#               Word(value='Sort', confidence=1.0),
#               Word(value='to', confidence=1.0),
#               Word(value='sort', confidence=1.0),
#               Word(value='a', confidence=1.0),
#               Word(value='list', confidence=1.0),
#               Word(value='of', confidence=1.0),
#               Word(value='n', confidence=0.91),
#               Word(value='[9', confidence=0.96),
#               Word(value='pts]', confidence=0.85),
#             ]
#           ),
#           Line(
#             (words): [Word(value='integers', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='Restriction', confidence=0.96)]
#           ),
#           Line(
#             (words): [
#               Word(value='e', confidence=0.71),
#               Word(value='of', confidence=1.0),
#               Word(value='what?', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='between', confidence=0.99),
#               Word(value='0', confidence=0.99),
#               Word(value='and', confidence=1.0),
#               Word(value='7', confidence=1.0),
#               Word(value='inclusive?', confidence=0.91),
#             ]
#           ),
#           Line(
#             (words): [Word(value='MV', confidence=0.74)]
#           ),
#           Line(
#             (words): [
#               Word(value='between', confidence=1.0),
#               Word(value='0', confidence=1.0),
#               Word(value='and', confidence=1.0),
#               Word(value='nign', confidence=0.59),
#               Word(value='inclusive?', confidence=0.99),
#             ]
#           ),
#           Line(
#             (words): [Word(value='mlgw', confidence=0.39)]
#           ),
#           Line(
#             (words): [
#               Word(value='between', confidence=1.0),
#               Word(value='n', confidence=0.99),
#               Word(value='and', confidence=1.0),
#               Word(value='n3', confidence=0.98),
#               Word(value='inclusive?', confidence=1.0),
#             ]
#           ),
#         ]
#         (artefacts): []
#       )]
#     ),
#     Page(
#       dimensions=(1656, 1190)
#       (blocks): [Block(
#         (lines): [
#           Line(
#             (words): [
#               Word(value='4.', confidence=1.0),
#               Word(value='We', confidence=1.0),
#               Word(value='are', confidence=1.0),
#               Word(value='using', confidence=1.0),
#               Word(value='counting', confidence=1.0),
#               Word(value='sort', confidence=1.0),
#               Word(value='to', confidence=1.0),
#               Word(value='sort', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='following', confidence=1.0),
#               Word(value='array', confidence=1.0),
#               Word(value='of', confidence=0.97),
#               Word(value='numbers.', confidence=1.0),
#               Word(value='The', confidence=1.0),
#               Word(value='?', confidence=1.0),
#               Word(value='mean', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='values', confidence=0.99),
#               Word(value='are', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [Word(value='unknown:', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='Index', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='0', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='1', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='2', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='3', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='4', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='5', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='6', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='Value', confidence=0.99)]
#           ),
#           Line(
#             (words): [Word(value='?', confidence=0.93)]
#           ),
#           Line(
#             (words): [Word(value='?', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='?', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='2', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='?', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='3', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='?', confidence=1.0)]
#           ),
#           Line(
#             (words): [
#               Word(value='(a)', confidence=1.0),
#               Word(value='Here', confidence=1.0),
#               Word(value='is', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='helper', confidence=0.99),
#               Word(value='array', confidence=1.0),
#               Word(value='POS', confidence=1.0),
#               Word(value='after', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='first', confidence=0.99),
#               Word(value='(non-cumulative)', confidence=0.47),
#               Word(value='step.', confidence=1.0),
#               Word(value='Fill', confidence=0.96),
#               Word(value='in', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='blanks:', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='[6', confidence=0.66),
#               Word(value='pts)', confidence=0.93),
#             ]
#           ),
#           Line(
#             (words): [Word(value='Index', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='0', confidence=0.96)]
#           ),
#           Line(
#             (words): [Word(value='1', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='2', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='3', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='Value', confidence=0.98)]
#           ),
#           Line(
#             (words): [Word(value='2', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='3', confidence=1.0)]
#           ),
#           Line(
#             (words): [
#               Word(value='(b)', confidence=1.0),
#               Word(value='Here', confidence=1.0),
#               Word(value='is', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='helper', confidence=1.0),
#               Word(value='array', confidence=1.0),
#               Word(value='POS', confidence=1.0),
#               Word(value='after', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='second', confidence=0.97),
#               Word(value='(cumulative)', confidence=1.0),
#               Word(value='step.', confidence=0.95),
#               Word(value='Fill', confidence=1.0),
#               Word(value='in', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='blanks:', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='6', confidence=0.94),
#               Word(value='pts)', confidence=0.69),
#             ]
#           ),
#           Line(
#             (words): [Word(value='Index', confidence=0.99)]
#           ),
#           Line(
#             (words): [Word(value='0', confidence=0.99)]
#           ),
#           Line(
#             (words): [Word(value='1', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='2', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='3', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='Value', confidence=1.0)]
#           ),
#           Line(
#             (words): [
#               Word(value='2', confidence=0.85),
#               Word(value='5', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [Word(value='6', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='7', confidence=0.8)]
#           ),
#           Line(
#             (words): [
#               Word(value='[14', confidence=0.88),
#               Word(value='pts]', confidence=0.68),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='(c)', confidence=0.95),
#               Word(value='Fill', confidence=0.99),
#               Word(value='in', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='sorted', confidence=1.0),
#               Word(value='array', confidence=1.0),
#               Word(value='after', confidence=1.0),
#               Word(value='Counting', confidence=1.0),
#               Word(value='Sort', confidence=1.0),
#               Word(value='has', confidence=1.0),
#               Word(value='finished:', confidence=0.54),
#             ]
#           ),
#           Line(
#             (words): [Word(value='Index', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='0', confidence=0.99)]
#           ),
#           Line(
#             (words): [Word(value='1', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='2', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='3', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='4', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='5', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='6', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='2', confidence=0.99)]
#           ),
#           Line(
#             (words): [Word(value='3', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='Value', confidence=0.99)]
#           ),
#         ]
#         (artefacts): []
#       )]
#     ),
#     Page(
#       dimensions=(1520, 1190)
#       (blocks): [Block(
#         (lines): [
#           Line(
#             (words): [
#               Word(value='5.', confidence=1.0),
#               Word(value='Suppose', confidence=1.0),
#               Word(value='Radix', confidence=1.0),
#               Word(value='Sort', confidence=1.0),
#               Word(value='is', confidence=1.0),
#               Word(value='used', confidence=1.0),
#               Word(value='to', confidence=1.0),
#               Word(value='sort', confidence=1.0),
#               Word(value='the', confidence=0.99),
#               Word(value='following', confidence=0.99),
#               Word(value='list', confidence=0.99),
#               Word(value='of', confidence=1.0),
#               Word(value='strings.', confidence=1.0),
#               Word(value='Show', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='state', confidence=0.96),
#               Word(value='of', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='list', confidence=0.86),
#               Word(value='after', confidence=1.0),
#               Word(value='[10', confidence=0.97),
#               Word(value='pts)', confidence=0.73),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='each', confidence=1.0),
#               Word(value='iteration', confidence=0.72),
#               Word(value='of', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='underlying', confidence=0.5),
#               Word(value='sort.', confidence=0.99),
#             ]
#           ),
#           Line(
#             (words): [Word(value='Start', confidence=0.97)]
#           ),
#           Line(
#             (words): [
#               Word(value='DIG', confidence=1.0),
#               Word(value='DIE', confidence=1.0),
#               Word(value='BID', confidence=1.0),
#               Word(value='DAD', confidence=1.0),
#               Word(value='BAD', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='After', confidence=1.0),
#               Word(value='Iteration', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [Word(value='DIG', confidence=0.52)]
#           ),
#           Line(
#             (words): [Word(value='1', confidence=1.0)]
#           ),
#           Line(
#             (words): [
#               Word(value='BID', confidence=0.9),
#               Word(value='DAD', confidence=0.88),
#               Word(value='6AD', confidence=0.63),
#               Word(value='VIE', confidence=0.39),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='After', confidence=1.0),
#               Word(value='Iteration', confidence=1.0),
#               Word(value='2', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='DA)', confidence=0.61),
#               Word(value='BAD', confidence=0.7),
#               Word(value='BIP', confidence=0.53),
#               Word(value='PIE', confidence=0.6),
#               Word(value='PIG', confidence=0.96),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='After', confidence=1.0),
#               Word(value='Iteration', confidence=0.99),
#               Word(value='3', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='BAD', confidence=0.9),
#               Word(value='BID', confidence=0.83),
#               Word(value='DAD', confidence=0.69),
#               Word(value='VIE', confidence=0.51),
#               Word(value='016', confidence=0.44),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='6.', confidence=0.99),
#               Word(value='Suppose', confidence=0.87),
#               Word(value='you', confidence=1.0),
#               Word(value='made', confidence=0.85),
#               Word(value='a', confidence=1.0),
#               Word(value='mistake', confidence=1.0),
#               Word(value='an', confidence=1.0),
#               Word(value='wrote', confidence=1.0),
#               Word(value='your', confidence=1.0),
#               Word(value='Radix', confidence=1.0),
#               Word(value='Sort', confidence=1.0),
#               Word(value='code', confidence=0.99),
#               Word(value='sO', confidence=0.58),
#               Word(value='that', confidence=1.0),
#               Word(value='it', confidence=1.0),
#               Word(value='sorted', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='leftmost', confidence=0.96),
#               Word(value='[10', confidence=0.82),
#               Word(value='pts]', confidence=0.91),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='digit', confidence=1.0),
#               Word(value='first,', confidence=1.0),
#               Word(value='then', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='next', confidence=1.0),
#               Word(value='leftmost,', confidence=0.99),
#               Word(value='and', confidence=1.0),
#               Word(value='sO', confidence=0.63),
#               Word(value='on.', confidence=1.0),
#               Word(value='Suppose', confidence=1.0),
#               Word(value='your', confidence=1.0),
#               Word(value='Broken', confidence=0.91),
#               Word(value='Radix', confidence=0.66),
#               Word(value='Sort', confidence=1.0),
#               Word(value='is', confidence=1.0),
#               Word(value='used', confidence=0.76),
#               Word(value='with', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='the', confidence=1.0),
#               Word(value='following', confidence=1.0),
#               Word(value='list', confidence=0.79),
#               Word(value='of', confidence=1.0),
#               Word(value='strings.', confidence=0.92),
#               Word(value='Show', confidence=0.97),
#               Word(value='the', confidence=1.0),
#               Word(value='state', confidence=1.0),
#               Word(value='of', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='list', confidence=0.99),
#               Word(value='after', confidence=0.81),
#               Word(value='each', confidence=1.0),
#               Word(value='iteration', confidence=1.0),
#               Word(value='of', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='underlying', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [Word(value='sort.', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='Start', confidence=0.9)]
#           ),
#           Line(
#             (words): [
#               Word(value='824', confidence=1.0),
#               Word(value='126', confidence=1.0),
#               Word(value='844', confidence=1.0),
#               Word(value='240', confidence=1.0),
#               Word(value='840', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [Word(value='Iteration', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='After', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='1', confidence=1.0)]
#           ),
#           Line(
#             (words): [
#               Word(value='126', confidence=0.98),
#               Word(value='240', confidence=1.0),
#               Word(value='824', confidence=0.99),
#               Word(value='&u4', confidence=0.28),
#               Word(value='840', confidence=0.7),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='After', confidence=1.0),
#               Word(value='Iteration', confidence=1.0),
#               Word(value='2', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='126', confidence=1.0),
#               Word(value='824', confidence=0.98),
#               Word(value='240', confidence=1.0),
#               Word(value='844', confidence=0.96),
#               Word(value='&u0', confidence=0.72),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='After', confidence=0.98),
#               Word(value='Iteration', confidence=0.99),
#               Word(value='3', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='240', confidence=1.0),
#               Word(value='840', confidence=0.98),
#               Word(value='824', confidence=0.99),
#               Word(value='844', confidence=0.71),
#               Word(value='126', confidence=0.97),
#             ]
#           ),
#         ]
#         (artefacts): []
#       )]
#     ),
#     Page(
#       dimensions=(1608, 1190)
#       (blocks): [Block(
#         (lines): [
#           Line(
#             (words): [
#               Word(value='7.', confidence=1.0),
#               Word(value='Suppose', confidence=1.0),
#               Word(value='Radix', confidence=1.0),
#               Word(value='Sort', confidence=0.92),
#               Word(value='(with', confidence=1.0),
#               Word(value='underlying', confidence=1.0),
#               Word(value='Counting', confidence=1.0),
#               Word(value='Sort)', confidence=0.99),
#               Word(value='is', confidence=1.0),
#               Word(value='applied', confidence=0.99),
#               Word(value='to', confidence=0.97),
#               Word(value='a', confidence=0.99),
#               Word(value='list', confidence=0.99),
#               Word(value='of', confidence=1.0),
#               Word(value='n?', confidence=0.97),
#               Word(value='integers', confidence=0.69),
#               Word(value='(in', confidence=0.62),
#               Word(value='base', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='10)', confidence=1.0),
#               Word(value='between', confidence=1.0),
#               Word(value='0', confidence=1.0),
#               Word(value='and', confidence=1.0),
#               Word(value='10logion', confidence=0.42),
#               Word(value='-', confidence=0.84),
#               Word(value='1', confidence=1.0),
#               Word(value='inclusive.', confidence=0.99),
#               Word(value='For', confidence=1.0),
#               Word(value='simplicity,', confidence=0.97),
#               Word(value='you', confidence=1.0),
#               Word(value='can', confidence=0.93),
#               Word(value='assume', confidence=0.96),
#               Word(value='that', confidence=1.0),
#               Word(value='logio', confidence=0.7),
#               Word(value='n', confidence=0.99),
#               Word(value='is', confidence=1.0),
#               Word(value='an', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [Word(value='integer.', confidence=0.99)]
#           ),
#           Line(
#             (words): [
#               Word(value='(a)', confidence=1.0),
#               Word(value='What', confidence=1.0),
#               Word(value='is', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='running', confidence=1.0),
#               Word(value='time', confidence=1.0),
#               Word(value='(in', confidence=1.0),
#               Word(value='e', confidence=0.68),
#               Word(value='notation)', confidence=1.0),
#               Word(value='of', confidence=1.0),
#               Word(value='Radix', confidence=1.0),
#               Word(value='Sort', confidence=1.0),
#               Word(value='in', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='above', confidence=1.0),
#               Word(value='scenario?', confidence=0.99),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='[4', confidence=1.0),
#               Word(value='pts]', confidence=0.91),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='e', confidence=0.76),
#               Word(value='of', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='scenario', confidence=1.0),
#               Word(value='described', confidence=1.0),
#               Word(value='above?', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='n', confidence=0.83),
#               Word(value='@', confidence=0.29),
#               Word(value='W', confidence=0.69),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='(b)', confidence=1.0),
#               Word(value='Show', confidence=0.9),
#               Word(value='your', confidence=1.0),
#               Word(value='work', confidence=1.0),
#               Word(value='for', confidence=1.0),
#               Word(value='(a).', confidence=0.99),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='[6', confidence=0.81),
#               Word(value='pts]', confidence=0.86),
#             ]
#           ),
#           Line(
#             (words): [Word(value=':', confidence=0.8)]
#           ),
#           Line(
#             (words): [Word(value='beuxt', confidence=0.43)]
#           ),
#           Line(
#             (words): [Word(value='.', confidence=0.68)]
#           ),
#           Line(
#             (words): [Word(value='(O-k(coz', confidence=0.39)]
#           ),
#           Line(
#             (words): [
#               Word(value='10,0', confidence=0.56),
#               Word(value='0-9)', confidence=0.99),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='yo', confidence=0.35),
#               Word(value='o', confidence=0.58),
#               Word(value='digis', confidence=0.31),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='lime', confidence=0.69),
#               Word(value='Cowplexily', confidence=0.45),
#               Word(value='', confidence=0.6),
#               Word(value='Cotuling', confidence=0.62),
#               Word(value='Sont', confidence=0.91),
#               Word(value='=', confidence=0.65),
#               Word(value='6GMtk)', confidence=0.55),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='', confidence=0.31),
#               Word(value='elmtl6)', confidence=0.19),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='Fwlcgos', confidence=0.24),
#               Word(value='N', confidence=0.36),
#               Word(value='hslist', confidence=0.23),
#               Word(value='Can', confidence=0.34),
#               Word(value='vtange', confidence=0.58),
#               Word(value='fiem', confidence=0.28),
#               Word(value='Cf', confidence=0.28),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='0', confidence=0.86),
#               Word(value='to', confidence=0.7),
#               Word(value='m-I', confidence=0.78),
#               Word(value='Gimcluive)', confidence=0.53),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='-', confidence=0.51),
#               Word(value='Hoyimu', confidence=0.48),
#               Word(value='W', confidence=0.33),
#               Word(value='mumbvc', confidence=0.41),
#               Word(value='ok', confidence=0.79),
#               Word(value='digrls', confidence=0.28),
#               Word(value='in', confidence=0.48),
#               Word(value='aM', confidence=0.33),
#               Word(value='inkeguu', confidence=0.37),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='=', confidence=0.38),
#               Word(value='logo', confidence=0.57),
#               Word(value='72', confidence=0.29),
#               Word(value='C-1000,', confidence=0.35),
#             ]
#           ),
#           Line(
#             (words): [Word(value='Alislolds', confidence=0.41)]
#           ),
#           Line(
#             (words): [
#               Word(value='oA', confidence=0.37),
#               Word(value='valu', confidence=0.59),
#               Word(value=':', confidence=0.38),
#               Word(value='a44', confidence=0.54),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='wAas', confidence=0.28),
#               Word(value='cuigils-3.', confidence=0.37),
#               Word(value='leg.looo)', confidence=0.43),
#               Word(value='JPuA', confidence=0.18),
#               Word(value='grvurall', confidence=0.36),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='Time', confidence=0.57),
#               Word(value='cowplesily', confidence=0.49),
#               Word(value='jac', confidence=0.82),
#               Word(value='yodix', confidence=0.53),
#               Word(value='sor4', confidence=0.33),
#               Word(value='.', confidence=0.74),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='sivce', confidence=0.51),
#               Word(value='wecovlipe', confidence=0.45),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='ousume', confidence=0.51),
#               Word(value='16', confidence=0.56),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='l9g,m', confidence=0.46),
#               Word(value='is', confidence=0.91),
#               Word(value='QAA', confidence=0.4),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='-', confidence=0.37),
#               Word(value='OClog', confidence=0.8),
#               Word(value='M', confidence=0.84),
#               Word(value='Cmtto))', confidence=0.45),
#             ]
#           ),
#           Line(
#             (words): [Word(value='I0', confidence=0.56)]
#           ),
#           Line(
#             (words): [Word(value='inleguc', confidence=0.4)]
#           ),
#           Line(
#             (words): [
#               Word(value='5', confidence=0.45),
#               Word(value='G', confidence=0.49),
#               Word(value='Gmlog', confidence=0.58),
#               Word(value='M', confidence=0.86),
#               Word(value='€', confidence=0.97),
#               Word(value='Iblog,', confidence=0.75),
#               Word(value='M', confidence=0.96),
#               Word(value=')', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [Word(value='jo', confidence=0.79)]
#           ),
#           Line(
#             (words): [Word(value='=)', confidence=0.76)]
#           ),
#           Line(
#             (words): [
#               Word(value='wejor', confidence=0.55),
#               Word(value='lene', confidence=0.28),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='Cmlos', confidence=0.27),
#               Word(value='w)', confidence=0.97),
#             ]
#           ),
#           Line(
#             (words): [Word(value='0', confidence=0.73)]
#           ),
#           Line(
#             (words): [
#               Word(value='is', confidence=0.88),
#               Word(value='yust', confidence=0.49),
#               Word(value='a', confidence=0.98),
#               Word(value='Igae', confidence=0.27),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='-', confidence=0.88),
#               Word(value='6', confidence=0.83),
#               Word(value='Glgm)', confidence=0.31),
#             ]
#           ),
#           Line(
#             (words): [Word(value=''9,10', confidence=0.52)]
#           ),
#         ]
#         (artefacts): []
#       )]
#     ),
#     Page(
#       dimensions=(1536, 1190)
#       (blocks): [Block(
#         (lines): [
#           Line(
#             (words): [
#               Word(value='8.', confidence=1.0),
#               Word(value='Suppose', confidence=0.99),
#               Word(value='we', confidence=1.0),
#               Word(value='run', confidence=0.68),
#               Word(value='Radix', confidence=1.0),
#               Word(value='Sort', confidence=1.0),
#               Word(value='on', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='following', confidence=0.99),
#               Word(value='list', confidence=0.68),
#               Word(value='where', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='digit', confidence=0.91),
#               Word(value='x', confidence=0.79),
#               Word(value='is', confidence=1.0),
#               Word(value='unknown:', confidence=0.98),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='[10', confidence=0.98),
#               Word(value='pts]', confidence=0.55),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='Original', confidence=1.0),
#               Word(value='List', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [Word(value='6x2', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='46x', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='108', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='8x8', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='28x', confidence=1.0)]
#           ),
#           Line(
#             (words): [
#               Word(value='After', confidence=1.0),
#               Word(value='Iteration', confidence=1.0),
#               Word(value='1', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [Word(value='6x2', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='46x', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='28x', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='108', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='8x8', confidence=1.0)]
#           ),
#           Line(
#             (words): [
#               Word(value='After', confidence=1.0),
#               Word(value='Iteration', confidence=0.95),
#               Word(value='2', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [Word(value='108', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='6x2', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='8x8', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='46x', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='28x', confidence=0.98)]
#           ),
#           Line(
#             (words): [
#               Word(value='After', confidence=1.0),
#               Word(value='Iteration', confidence=1.0),
#               Word(value='3', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [Word(value='108', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='28x', confidence=0.53)]
#           ),
#           Line(
#             (words): [Word(value='46x', confidence=0.99)]
#           ),
#           Line(
#             (words): [Word(value='6x2', confidence=1.0)]
#           ),
#           Line(
#             (words): [Word(value='8x8', confidence=1.0)]
#           ),
#           Line(
#             (words): [
#               Word(value='What', confidence=1.0),
#               Word(value='are', confidence=1.0),
#               Word(value='the', confidence=1.0),
#               Word(value='possible', confidence=1.0),
#               Word(value='digit', confidence=1.0),
#               Word(value='values', confidence=0.96),
#               Word(value='for', confidence=1.0),
#               Word(value='x?', confidence=1.0),
#               Word(value='List', confidence=1.0),
#               Word(value='them', confidence=1.0),
#               Word(value='explicitly', confidence=0.84),
#               Word(value='and', confidence=1.0),
#               Word(value='in', confidence=1.0),
#               Word(value='order.', confidence=1.0),
#             ]
#           ),
#           Line(
#             (words): [
#               Word(value='Possible', confidence=0.99),
#               Word(value='Values', confidence=1.0),
#               Word(value='for', confidence=1.0),
#               Word(value='X', confidence=0.58),
#               Word(value='are:', confidence=0.98),
#             ]
#           ),
#           Line(
#             (words): [Word(value='2,3,4,5', confidence=0.55)]
#           ),
#           Line(
#             (words): [
#               Word(value='Scratch', confidence=1.0),
#               Word(value='work;', confidence=1.0),
#               Word(value='Not', confidence=0.99),
#               Word(value='graded', confidence=0.95),
#               Word(value='but', confidence=1.0),
#               Word(value='may', confidence=0.87),
#               Word(value='be', confidence=1.0),
#               Word(value='used', confidence=0.98),
#               Word(value='for', confidence=1.0),
#               Word(value='regrade', confidence=1.0),
#               Word(value='partial', confidence=0.95),
#               Word(value='credit:', confidence=0.89),
#             ]
#           ),
#         ]
#         (artefacts): []
#       )]
#     ),
#   ]
# )
